# %%
# pip install opencv-contrib-python
import os
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt
print(cv.__version__)
# Out:
# 4.10.0

# %%
# reading a image in an external window
image = cv.imread(r'C:\Users\Asif Sayyed\Documents\GitHub\open-see-wee\image\ok.jpg')
cv.imshow('Image', image)
cv.waitKey(0)
cv.destroyAllWindows()

# %%
# displaying image in the ipynb file
# image variable is already defined above
image_rgb = cv.cvtColor(image, cv.COLOR_BGR2RGB)

plt.imshow(image_rgb)
plt.axis('off')
plt.show()

# %%
directory = r'C:\Users\Asif Sayyed\Documents\GitHub\open-see-wee\image'
# Out:
# Before writing image to disk, directory contents are: ['meme.jpeg', 'ok.jpg']

# %%
os.chdir(directory)
print('Before writing image to disk, directory contents are:', os.listdir(directory))
# Out:
# Before writing image to disk, directory contents are: ['meme.jpeg', 'ok.jpg']

# %%
image = cv.imread(r'..\image\ok.jpg')

dimension = image.shape
height = image.shape[0]
width = image.shape[1]
channel = image.shape[2]

print(channel)

# splitting image as 3 channels
blue = image[:,:,0]
green = image[:,:,1]
red = image[:,:,2]

print(blue, green, red)
# Out:
# 3
# [[243 242 242 ... 243 244 245]
#  [240 239 239 ... 240 241 243]
#  [197 197 196 ... 192 195 197]
#  ...
#  [119 120 121 ...  71  70  69]
#  [121 121 122 ...  70  68  67]
#  [121 122 123 ...  69  67  65]] [[255 254 254 ... 252 253 254]
#  [255 254 254 ... 252 253 255]
#  [216 216 215 ... 211 214 216]
#  ...
#  [148 149 150 ...  69  68  67]
#  [150 150 151 ...  68  66  65]
#  [150 151 152 ...  67  65  63]] [[255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [224 224 223 ... 219 222 224]
#  ...
#  [153 154 155 ...  68  67  66]
#  [155 155 156 ...  67  65  64]
#  [155 156 157 ...  66  64  62]]

# %%
cv.imwrite()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 cv.imwrite(filename, image)
#
# error: OpenCV(4.10.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:708: error: (-2:Unspecified error) could not find a writer for the specified extension in function 'cv::imwrite_'
